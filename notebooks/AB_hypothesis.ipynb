# %%
import sys
import os

# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.AB_hypothesis import ABHypothesisTesting

# %%
# Create an instance of the ABHypothesisTesting class
analysis = ABHypothesisTesting('../data/MachineLearningRating_v3.csv')

# Run the full analysis
print("Running full analysis:")
analysis.run_analysis()
# Out:
# Running full analysis:
# 1. Testing risk differences across provinces
#
# 2. Testing risk differences between postal codes
#
# 3. Testing margin differences between postal codes
#
# 4. Testing risk differences between genders
#
# Analyzing Results:
# Province Risk Difference: Fail to reject null hypothesis (p = 1.00000)
#
# PostalCode Risk Difference: Fail to reject null hypothesis (p = 1.00000)
#
# PostalCode Margin Difference: Fail to reject null hypothesis (p = 0.62687)
#
# Gender Risk Difference: Fail to reject null hypothesis (p = 1.00000)
#
#
# Visualizing Results:
# Additional Analysis:
# Average Margin by Province:
# Province
# 7    35.590527
# 0    25.833240
# 4    20.971484
# 1    20.550805
# 5    15.016059
# 6    10.958832
# 8    -3.414689
# 3    -6.433598
# 2   -13.558894
# Name: Margin, dtype: float64
#
# Risk Distribution by Gender:
# StatutoryRiskType    0
# Gender
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
#
# ...
