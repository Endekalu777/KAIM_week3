# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
scripts_path = os.path.abspath('/content/drive/MyDrive/model_analysis')
sys.path.append(scripts_path)
from model_analysis import ModelAnalysis

# %%
analysis = ModelAnalysis("/content/drive/MyDrive/w1_colab/MachineLearningRating_v3.csv")

# %%
analysis.handle_missing_values()

# %%
analysis.feature_engineering()

# %%
analysis.encoder()

# %%
analysis.train_test_split()

# %%
analysis.linear_model()
analysis.randomf_model()
analysis.xg_model()
analysis.shap_analysis()
# Out:
# Linear Regression MSE: 10611.430405280551
# Linear Regression R2 Score: 0.6663144782416593
# Random Forest MSE: 7556.925671076397
# Random Forest R2 Score: 0.7623659969359751
# XGBoost MSE: 8199.861984196657
# XGBoost R2 Score: 0.7421483136541662
